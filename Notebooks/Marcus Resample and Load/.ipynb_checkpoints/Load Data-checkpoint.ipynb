# %%
print_imports()
# Out:
# Loaded modules:
# numpy                np              1.14.0
# pandas               pd              0.22.0
# sklearn              sk              0.19.1
# keras                ks              2.1.4
#
# matplotlib           mpl             2.1.2
# matplotlib.pyplot    plt             N/A
# matplotlib.image     mpimg           N/A
# seaborn              sns             0.8.1
# PIL                  PIL             5.0.0
#
# ExergyUtilities      exergy          2.0.
#
# pyspark              pyspark         2.2.1

# %%
import os

# %%
data_path = r"/media/batman/WD20 Ext <Movies>/ConnHack2018"
company = 'Fresh'
csvfile = ''

# %%
data_path = r"/home/batman/Dropbox/DATA/Connhack"
csvfilename = r'SQLVora_march_full.csv'
file_path =  os.path.join(data_path, csvfilename)
file_path
# Out:
# '/home/batman/Dropbox/DATA/Connhack/SQLVora_march_full.csv'

# %%
df = pd.read_csv(file_path)

# %%
df
# Out:
#       METERID                   TSTAMP        ENERGY  POWER_ALL  \
# 0         201  2017-02-24 02:52:30.000  164021878000      48840
# 1         201  2017-02-24 02:52:32.000  164022149000      48840
# 2         201  2017-02-24 02:52:34.000  164022422000      48980
# 3         201  2017-02-24 02:52:36.000  164022692000      48560
# 4         201  2017-02-24 02:52:38.000  164022963000      48770
# 5         201  2017-02-24 02:52:40.000  164023233000      48740
# 6         201  2017-02-24 02:52:42.000  164023504000      48700
# 7         201  2017-02-24 02:52:44.000  164023776000      48950
# 8         201  2017-02-24 02:52:46.000  164024047000      48870
# 9         201  2017-02-24 02:52:48.000  164024321000      49530
# 10        201  2017-02-24 02:52:50.000  164024596000      49280
# 11        201  2017-02-24 02:52:52.000  164024869000      49250
# 12        201  2017-02-24 02:52:54.000  164025143000      49310
# 13        201  2017-02-24 02:52:56.000  164025416000      49140
# ...
